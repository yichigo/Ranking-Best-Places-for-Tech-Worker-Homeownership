# %%
import pandas as pd
import numpy as np
import os
from os import listdir
import math
from sklearn.model_selection import GridSearchCV, train_test_split 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import shap

# %%
FILE_IN = "./data/combined_data.csv"
df = pd.read_csv(FILE_IN)
print("Total number: ",len(df))
df.head()
# Out:
# Total number:  52714
# /Users/Strawberry/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0       zpid                   street    zip    city state  \
# 0           0  251033583        8017 Bestride Bnd  78744  AUSTIN    TX
# 1           1   29343368         4191 Westlake Dr  78746  AUSTIN    TX
# 2           2   29349366  6203 Shadow Mountain Dr  78731  AUSTIN    TX
# 3           3   29467905      5304 China Berry Rd  78744  AUSTIN    TX
# 4           4   29499672         8968 W Hove Loop  78749  AUSTIN    TX
#
#     latitude  longitude  FIPScounty propertyType  ...   edu_mean   edu_max  \
# 0  30.186200 -97.738800     48453.0          NaN  ...  55.667035  63.07768
# 1  30.333213 -97.799519     48453.0          NaN  ...  92.643080  92.64308
# 2  30.348746 -97.760890     48453.0          NaN  ...   6.943352  16.22703
# 3  30.193234 -97.737353     48453.0          NaN  ...  55.667035  63.07768
# 4  30.200092 -97.854377     48453.0          NaN  ...  42.879144  96.09233
#
#     edu_min  pop_2012  pop_2013 pop_2014  pop_2015  pop_2016  pop_2017  \
# 0  48.25639    854841    875463   901734    921545    939768    951750
# 1  92.64308    854841    875463   901734    921545    939768    951750
# 2   3.62122    854841    875463   901734    921545    939768    951750
# 3  48.25639    854841    875463   901734    921545    939768    951750
# 4   4.95380    854841    875463   901734    921545    939768    951750
#
#    pop_2018
# 0    964254
# 1    964254
# 2    964254
# 3    964254
# 4    964254
#
# [5 rows x 221 columns]

# %% [markdown]
# ### The data

# %%
# from crime number to crime rate
columns = df.columns[42:210].values

for var in columns:
    year = var.split("_")[1]
    df[var] = df[var]/df["pop_"+year]

# %%
# data preprocessing
target = "zestimatePrice"
features = df.columns[20:].values
features = np.append(features,["yearBuilt","finishedSqFt","bathrooms","bedrooms"])

colums = np.append(features, [target])
df_data = df[colums]

print("total number: ", len(df_data))
df_data = df_data.dropna()
print("number without nan: ",len(df_data))

df_data.head()
# Out:
# total number:  52714
# number without nan:  52322
#    Wage_MED_12  Wage_AVG_12  Wage_MED_13  Wage_AVG_13  Wage_MED_14  \
# 0      70175.0      70526.0      66331.0      73484.0      66331.0
# 1      70175.0      70526.0      66331.0      73484.0      66331.0
# 2      70175.0      70526.0      66331.0      73484.0      66331.0
# 3      70175.0      70526.0      66331.0      73484.0      66331.0
# 4      70175.0      70526.0      66331.0      73484.0      66331.0
#
#    Wage_AVG_14  Wage_MED_15  Wage_AVG_15  Wage_MED_16  Wage_AVG_16  ...  \
# 0      73016.0      65229.0      75089.0      76294.0      83922.0  ...
# 1      73016.0      65229.0      75089.0      76294.0      83922.0  ...
# 2      73016.0      65229.0      75089.0      76294.0      83922.0  ...
# 3      73016.0      65229.0      75089.0      76294.0      83922.0  ...
# 4      73016.0      65229.0      75089.0      76294.0      83922.0  ...
#
#    pop_2014  pop_2015  pop_2016  pop_2017  pop_2018  yearBuilt  finishedSqFt  \
# 0    901734    921545    939768    951750    964254     2019.0        2487.0
# 1    901734    921545    939768    951750    964254     2002.0        6135.0
# 2    901734    921545    939768    951750    964254     1977.0        2868.0
# 3    901734    921545    939768    951750    964254     2000.0        1485.0
# 4    901734    921545    939768    951750    964254     2000.0        1501.0
#
#    bathrooms  bedrooms  zestimatePrice
# 0        4.0         4          401942
# 1        6.0         5         2019998
# 2        4.0         5          807984
# 3        2.0         4          231655
# 4        2.0         3          391905
#
# [5 rows x 206 columns]

# %%
# train test datasets
X = df_data[features]
y = df_data[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Random Forest Model, grid search to find best parameter
RANDOM_STATE = 42
rfr = RandomForestRegressor(random_state = RANDOM_STATE, oob_score=True, n_jobs = -1)
param_grid = {'max_depth': [10,20,30],'n_estimators': [150,200,250]}
CV_rfr = GridSearchCV(estimator = rfr, param_grid = param_grid, cv =5, verbose = 3)

CV_rfr.fit(X_train, y_train)
print(CV_rfr.best_params_)
print(CV_rfr.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=10, n_estimators=150 ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=10, n_estimators=150, score=0.8909824905957655, total=  33.7s
# [CV] max_depth=10, n_estimators=150 ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   33.8s remaining:    0.0s
# [CV]  max_depth=10, n_estimators=150, score=0.8996877161913625, total=  17.8s
# [CV] max_depth=10, n_estimators=150 ..................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   51.8s remaining:    0.0s
# [CV]  max_depth=10, n_estimators=150, score=0.8912985617166997, total=  17.6s
# [CV] max_depth=10, n_estimators=150 ..................................
# [CV]  max_depth=10, n_estimators=150, score=0.8968860352684755, total=  19.7s
# [CV] max_depth=10, n_estimators=150 ..................................
# [CV]  max_depth=10, n_estimators=150, score=0.8933241098130406, total=  22.4s
# [CV] max_depth=10, n_estimators=200 ..................................
# [CV]  max_depth=10, n_estimators=200, score=0.8914061893484432, total=  26.7s
# [CV] max_depth=10, n_estimators=200 ..................................
# [CV]  max_depth=10, n_estimators=200, score=0.8995384764063282, total=  28.5s
# [CV] max_depth=10, n_estimators=200 ..................................
# [CV]  max_depth=10, n_estimators=200, score=0.8917357845151649, total=  29.7s
# [CV] max_depth=10, n_estimators=200 ..................................
# [CV]  max_depth=10, n_estimators=200, score=0.8964614664220639, total=  26.8s
# [CV] max_depth=10, n_estimators=200 ..................................
# [CV]  max_depth=10, n_estimators=200, score=0.8934497428526954, total=  25.8s
# [CV] max_depth=10, n_estimators=250 ..................................
# [CV]  max_depth=10, n_estimators=250, score=0.8914726560065834, total=  30.6s
# [CV] max_depth=10, n_estimators=250 ..................................
# [CV]  max_depth=10, n_estimators=250, score=0.8994027551387415, total=  33.0s
# [CV] max_depth=10, n_estimators=250 ..................................
# [CV]  max_depth=10, n_estimators=250, score=0.8916846372210601, total=  35.9s
# [CV] max_depth=10, n_estimators=250 ..................................
# [CV]  max_depth=10, n_estimators=250, score=0.8969150741161791, total=  32.3s
# [CV] max_depth=10, n_estimators=250 ..................................
# [CV]  max_depth=10, n_estimators=250, score=0.8928721044121418, total=  32.4s
# [CV] max_depth=20, n_estimators=150 ..................................
# [CV]  max_depth=20, n_estimators=150, score=0.8968981830288588, total=  22.9s
# [CV] max_depth=20, n_estimators=150 ..................................
# [CV]  max_depth=20, n_estimators=150, score=0.903435760613956, total=  23.4s
# [CV] max_depth=20, n_estimators=150 ..................................
# [CV]  max_depth=20, n_estimators=150, score=0.8984468500699132, total=  23.1s
# [CV] max_depth=20, n_estimators=150 ..................................
# [CV]  max_depth=20, n_estimators=150, score=0.90313768678535, total=  22.9s
# [CV] max_depth=20, n_estimators=150 ..................................
# [CV]  max_depth=20, n_estimators=150, score=0.8995803153197798, total=  23.1s
# [CV] max_depth=20, n_estimators=200 ..................................
# [CV]  max_depth=20, n_estimators=200, score=0.8974519580160365, total=  30.9s
# [CV] max_depth=20, n_estimators=200 ..................................
# [CV]  max_depth=20, n_estimators=200, score=0.9034966140594612, total=  30.8s
# [CV] max_depth=20, n_estimators=200 ..................................
# [CV]  max_depth=20, n_estimators=200, score=0.8984230148696817, total=  30.3s
# [CV] max_depth=20, n_estimators=200 ..................................
# [CV]  max_depth=20, n_estimators=200, score=0.9030420326935127, total=  30.8s
# [CV] max_depth=20, n_estimators=200 ..................................
# [CV]  max_depth=20, n_estimators=200, score=0.9001291913518041, total=  30.5s
# [CV] max_depth=20, n_estimators=250 ..................................
# [CV]  max_depth=20, n_estimators=250, score=0.8977196122009491, total=  38.1s
# [CV] max_depth=20, n_estimators=250 ..................................
# [CV]  max_depth=20, n_estimators=250, score=0.903507498382267, total=  38.4s
# [CV] max_depth=20, n_estimators=250 ..................................
# [CV]  max_depth=20, n_estimators=250, score=0.8985295035017675, total=  38.7s
# [CV] max_depth=20, n_estimators=250 ..................................
# [CV]  max_depth=20, n_estimators=250, score=0.9034091741777178, total=  40.4s
# [CV] max_depth=20, n_estimators=250 ..................................
# [CV]  max_depth=20, n_estimators=250, score=0.8994367636912275, total=  45.8s
# [CV] max_depth=30, n_estimators=150 ..................................
# [CV]  max_depth=30, n_estimators=150, score=0.8970864352995224, total=  25.6s
# [CV] max_depth=30, n_estimators=150 ..................................
# [CV]  max_depth=30, n_estimators=150, score=0.9032050486323361, total=  30.0s
# [CV] max_depth=30, n_estimators=150 ..................................
# [CV]  max_depth=30, n_estimators=150, score=0.8980947590036112, total=  35.1s
# [CV] max_depth=30, n_estimators=150 ..................................
# [CV]  max_depth=30, n_estimators=150, score=0.9028331986063275, total=  31.9s
# [CV] max_depth=30, n_estimators=150 ..................................
# [CV]  max_depth=30, n_estimators=150, score=0.8983138920264337, total=  30.7s
# [CV] max_depth=30, n_estimators=200 ..................................
# [CV]  max_depth=30, n_estimators=200, score=0.8976737322165518, total=  42.3s
# [CV] max_depth=30, n_estimators=200 ..................................
# [CV]  max_depth=30, n_estimators=200, score=0.9033707119523507, total=  40.7s
# [CV] max_depth=30, n_estimators=200 ..................................
# [CV]  max_depth=30, n_estimators=200, score=0.8980403449302556, total=  42.7s
# [CV] max_depth=30, n_estimators=200 ..................................
# [CV]  max_depth=30, n_estimators=200, score=0.902767486628522, total=  42.9s
# [CV] max_depth=30, n_estimators=200 ..................................
# [CV]  max_depth=30, n_estimators=200, score=0.8986896971783251, total=  35.5s
# [CV] max_depth=30, n_estimators=250 ..................................
# [CV]  max_depth=30, n_estimators=250, score=0.8978843891677489, total=  41.6s
# [CV] max_depth=30, n_estimators=250 ..................................
# [CV]  max_depth=30, n_estimators=250, score=0.9030905048838804, total=  43.5s
# [CV] max_depth=30, n_estimators=250 ..................................
# [CV]  max_depth=30, n_estimators=250, score=0.898035743007018, total=  42.5s
# [CV] max_depth=30, n_estimators=250 ..................................
# [CV]  max_depth=30, n_estimators=250, score=0.9031227246536143, total=  43.9s
# [CV] max_depth=30, n_estimators=250 ..................................
# [CV]  max_depth=30, n_estimators=250, score=0.8981197664657216, total=  42.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 24.5min finished
# {'max_depth': 20, 'n_estimators': 250}
# 0.9005205148366325

# %%
# model fit
RANDOM_STATE = 42
regr = RandomForestRegressor(random_state = RANDOM_STATE, oob_score=True, n_jobs = -1,
                             max_depth=20,#CV_rfr.best_params_['max_depth'],
                             n_estimators=200)#CV_rfr.best_params_['n_estimators'])


regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#            oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
from sklearn.metrics import r2_score
train_score = r2_score(y_train, regr.predict(X_train))
test_score = r2_score(y_test, regr.predict(X_test))

plt.rcParams["figure.figsize"] = (10, 10) # (w, h)
fig, ax = plt.subplots()
plt.scatter(y_train,regr.predict(X_train), s=5, c = 'blue',label = 'Train, R$^{2}$ ='+str(train_score)[:6])
plt.scatter(y_test,regr.predict(X_test), s=5, c = 'red', label = 'Test, R$^{2}$ ='+str(test_score)[:6])
plt.xlim((np.min(y),8*np.median(y)))
plt.ylim((np.min(y),8*np.median(y)))
ax.set_title('Predicted vs Actural')
ax.set_xlabel('Actural Value')
ax.set_ylabel('Predicted Value')
plt.legend( loc='lower right')
plt.tight_layout()
plt.savefig('./plot/'+'RF_performance.png')

# %%
# rank feature inportance
num_features = 20
importances = regr.feature_importances_
std = np.std([tree.feature_importances_ for tree in regr.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

var_sorted = features[indices]
var_imp_sorted = importances[indices]

plt.rcParams["figure.figsize"] = (10, num_features/3) # (w, h)
fig, ax = plt.subplots()
ax.barh(var_sorted[:num_features], var_imp_sorted[:num_features],
        yerr=std[indices][:num_features], ecolor='black',
        color = None, align="center")
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_title('Feature Importances')
plt.tight_layout()
plt.savefig('./plot/'+'RF_feature_imp.png')

# %%
var_sorted[:20]
# Out:
# array(['finishedSqFt', 'weather_jul', 'weather_aug', 'yearBuilt',
#        'Wage_AVG_14', 'Wage_MED_14', 'Wage_AVG_15', 'Wage_MED_15',
#        'Wage_MED_13', 'Wage_MED_12', 'edu_max', 'bathrooms', 'bedrooms',
#        'edu_mean', 'edu_min', 'edu_median', 'actual_2015_violent-crime',
#        'actual_2017_arson', 'weather_mar', 'actual_2013_rape-legacy'],
#       dtype=object)

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(regr)

# %%
# Calculate shap_values
num_shap = 500
shap_values = explainer.shap_values(X_train[:num_shap])

# %%
# plot
shap.summary_plot(shap_values, X_train[:num_shap],
                  plot_size=(20,10),#'auto'
                  max_display = 20,
                  show=False
                 )
plt.savefig("./plot/RF_shap.png")
